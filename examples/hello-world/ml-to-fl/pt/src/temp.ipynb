# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from net import FraudNet, AttentionTransformerFraudNet, EnhancedFraudNet  # Import fraud detection model
from data import get_dataloaders_fraud  # Import dataset functions
from evaluation import evaluate_model  # Import evaluation function
from train import train_model, set_all_seeds  # Import training function from train.py
import pandas as pd
import sys
from plot import plot_metrics, plot_confusion_matrices, plot_aucpr
import pickle


set_all_seeds(42)

# Set dataset path
DATASET_PATH = "/home/khoa/Khoa/outsource/na_thesis/examples/hello-world/ml-to-fl/pt/src/data/creditcard.csv"
DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"

# Training hyperparameters
batch_size = 64
num_epochs = 15
learning_rate = 0.00003


df = pd.read_csv(DATASET_PATH)
input_size = df.shape[1] - 1
print(f"Detected input size: {input_size}")

train_loader, valid_loader, test_loader, class_weights = get_dataloaders_fraud(
    DATASET_PATH, batch_size=batch_size, use_smote=True, plot=True, save_plot_dir=save_plot_dir
)

# %%
model = FraudNet(input_size=input_size).to(DEVICE)
model_name = model.__class__.__name__

save_plot_dir = f'plot_{model_name}_{batch_size}_{num_epochs}_{learning_rate}'
class_weights = class_weights
pos_weight = torch.tensor([class_weights[1] / class_weights[0]], device=DEVICE)

# Loss Function (No weight balancing since using SMOTE)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Call `train.py` instead of writing the training loop here
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', patience=3, verbose=True
)

train_loss_list, train_metrics_list, valid_metrics_list, test_metrics = train_model(
    model, num_epochs, train_loader, valid_loader, test_loader, optimizer,
    criterion, DEVICE, scheduler=scheduler, stochastic=True
)

# Create metrics directory if it doesn't exist
metrics_dir = 'metrics'
os.makedirs(metrics_dir, exist_ok=True)

# Save training metrics
metrics_data = {
    'train_metrics': train_metrics_list,
    'valid_metrics': valid_metrics_list,
    'test_metrics': test_metrics,
    'train_loss': train_loss_list
}

metrics_file = os.path.join(metrics_dir, f"{model_name}_{batch_size}_{num_epochs}_{learning_rate}_metrics.pickle")
with open(metrics_file, 'wb') as f:
    pickle.dump(metrics_data, f)

print(f"Metrics saved to {metrics_file}")

# Create plots
plot_metrics(train_metrics_list, fig_name="Training Metrics", save_path=f"{save_plot_dir}/train_metrics.png")
plot_metrics(valid_metrics_list, fig_name="Validation Metrics", save_path=f"{save_plot_dir}/valid_metrics.png")
plot_confusion_matrices(model, test_loader, threshold=0.85, save_path=f"{save_plot_dir}/confusion_matrix.png")
plot_aucpr(model, test_loader, device=DEVICE, save_path=f"{save_plot_dir}/auc_pr.png")

# Save the trained model
best_model_path = "best_model.pth"
model.load_state_dict(torch.load(best_model_path))
print("Loaded best model from training phase.")

# Save the best model explicitly at a clear location for future usage
final_model_path = f"./best_{model_name}_{batch_size}_{num_epochs}_{learning_rate}_model.pth"
torch.save(model.state_dict(), final_model_path)
print(f"Final best model saved explicitly at {final_model_path}")

# Evaluate model
print("Evaluating Model on Test Set...")
evaluate_model(model, test_loader, DEVICE)
# Out:
# Starting Training...
# [Epoch 1, Batch 1] Loss: 1.0648
# [Epoch 1, Batch 369] Loss: 0.6910
# [Epoch 1, Batch 737] Loss: 0.5359
# [Epoch 1, Batch 1105] Loss: 0.4662
# [Epoch 1, Batch 1473] Loss: 0.3306
# [Epoch 1, Batch 1841] Loss: 0.4013
# [Epoch 1, Batch 2209] Loss: 0.2471
# [Epoch 1, Batch 2577] Loss: 0.2222
# [Epoch 1, Batch 2945] Loss: 0.3184
# [Epoch 1, Batch 3313] Loss: 0.1858
# [Epoch 1, Batch 3681] Loss: 0.3601
# Epoch 1/15: Train Loss: 0.3886 | Train Acc: 96.66% | Valid Loss: 0.2123 | Valid Acc: 99.82% | Valid Precision: 48.21% | Valid Recall: 86.17% | Valid F1-score: 61.83% | Valid AUC-PR: 77.84%
# Time Elapsed: 0.26 minutes
# Model improved. Saving best model.
# [Epoch 2, Batch 1] Loss: 0.2097
# [Epoch 2, Batch 369] Loss: 0.2112
# [Epoch 2, Batch 737] Loss: 0.1210
# [Epoch 2, Batch 1105] Loss: 0.1824
# [Epoch 2, Batch 1473] Loss: 0.1841
# [Epoch 2, Batch 1841] Loss: 0.1528
# [Epoch 2, Batch 2209] Loss: 0.1558
# [Epoch 2, Batch 2577] Loss: 0.3327
# [Epoch 2, Batch 2945] Loss: 0.2081
# [Epoch 2, Batch 3313] Loss: 0.1061
# [Epoch 2, Batch 3681] Loss: 0.1648
# Epoch 2/15: Train Loss: 0.1775 | Train Acc: 97.88% | Valid Loss: 0.0987 | Valid Acc: 99.70% | Valid Precision: 34.30% | Valid Recall: 88.30% | Valid F1-score: 49.40% | Valid AUC-PR: 81.21%
# Time Elapsed: 0.50 minutes
# [Epoch 3, Batch 1] Loss: 0.1859
# [Epoch 3, Batch 369] Loss: 0.1265
# [Epoch 3, Batch 737] Loss: 0.0607
# [Epoch 3, Batch 1105] Loss: 0.2085
# [Epoch 3, Batch 1473] Loss: 0.1581
# [Epoch 3, Batch 1841] Loss: 0.2197
# [Epoch 3, Batch 2209] Loss: 0.1178
# [Epoch 3, Batch 2577] Loss: 0.0423
# [Epoch 3, Batch 2945] Loss: 0.1352
# [Epoch 3, Batch 3313] Loss: 0.0901
# [Epoch 3, Batch 3681] Loss: 0.1224
# Epoch 3/15: Train Loss: 0.1231 | Train Acc: 98.52% | Valid Loss: 0.0606 | Valid Acc: 99.71% | Valid Precision: 35.19% | Valid Recall: 87.23% | Valid F1-score: 50.15% | Valid AUC-PR: 79.53%
# Time Elapsed: 0.75 minutes
# [Epoch 4, Batch 1] Loss: 0.0844
# [Epoch 4, Batch 369] Loss: 0.1334
# [Epoch 4, Batch 737] Loss: 0.1015
# [Epoch 4, Batch 1105] Loss: 0.1877
# [Epoch 4, Batch 1473] Loss: 0.0721
# [Epoch 4, Batch 1841] Loss: 0.0579
# [Epoch 4, Batch 2209] Loss: 0.0526
# [Epoch 4, Batch 2577] Loss: 0.0316
# [Epoch 4, Batch 2945] Loss: 0.0638
# [Epoch 4, Batch 3313] Loss: 0.0414
# [Epoch 4, Batch 3681] Loss: 0.0451
# Epoch 4/15: Train Loss: 0.1022 | Train Acc: 99.11% | Valid Loss: 0.0671 | Valid Acc: 99.48% | Valid Precision: 22.62% | Valid Recall: 88.30% | Valid F1-score: 36.01% | Valid AUC-PR: 80.97%
# Time Elapsed: 0.99 minutes
# [Epoch 5, Batch 1] Loss: 0.0342
# [Epoch 5, Batch 369] Loss: 0.0317
# [Epoch 5, Batch 737] Loss: 0.1452
# [Epoch 5, Batch 1105] Loss: 0.0602
# [Epoch 5, Batch 1473] Loss: 0.1984
# [Epoch 5, Batch 1841] Loss: 0.0208
# [Epoch 5, Batch 2209] Loss: 0.0605
# [Epoch 5, Batch 2577] Loss: 0.0299
# [Epoch 5, Batch 2945] Loss: 0.1399
# [Epoch 5, Batch 3313] Loss: 0.0179
# [Epoch 5, Batch 3681] Loss: 0.0411
# Epoch 5/15: Train Loss: 0.0740 | Train Acc: 99.37% | Valid Loss: 0.0528 | Valid Acc: 99.62% | Valid Precision: 28.57% | Valid Recall: 87.23% | Valid F1-score: 43.04% | Valid AUC-PR: 79.48%
# Time Elapsed: 1.23 minutes
# Epoch 00005: reducing learning rate of group 0 to 3.0000e-06.
# [Epoch 6, Batch 1] Loss: 0.0272
# [Epoch 6, Batch 369] Loss: 0.1892
# [Epoch 6, Batch 737] Loss: 0.0114
# [Epoch 6, Batch 1105] Loss: 0.1402
# [Epoch 6, Batch 1473] Loss: 0.0240
# [Epoch 6, Batch 1841] Loss: 0.0475
# [Epoch 6, Batch 2209] Loss: 0.0146
# [Epoch 6, Batch 2577] Loss: 0.1549
# [Epoch 6, Batch 2945] Loss: 0.0493
# [Epoch 6, Batch 3313] Loss: 0.1293
# [Epoch 6, Batch 3681] Loss: 0.1370
# Epoch 6/15: Train Loss: 0.0623 | Train Acc: 99.44% | Valid Loss: 0.0532 | Valid Acc: 99.57% | Valid Precision: 26.11% | Valid Recall: 87.23% | Valid F1-score: 40.20% | Valid AUC-PR: 79.21%
# Time Elapsed: 1.49 minutes
# [Epoch 7, Batch 1] Loss: 0.0185
# [Epoch 7, Batch 369] Loss: 0.0669
# [Epoch 7, Batch 737] Loss: 0.0237
# [Epoch 7, Batch 1105] Loss: 0.0510
# [Epoch 7, Batch 1473] Loss: 0.0415
# [Epoch 7, Batch 1841] Loss: 0.0637
# [Epoch 7, Batch 2209] Loss: 0.1633
# [Epoch 7, Batch 2577] Loss: 0.0630
# [Epoch 7, Batch 2945] Loss: 0.0278
# [Epoch 7, Batch 3313] Loss: 0.0295
# [Epoch 7, Batch 3681] Loss: 0.0476
# Epoch 7/15: Train Loss: 0.0678 | Train Acc: 99.41% | Valid Loss: 0.0516 | Valid Acc: 99.59% | Valid Precision: 27.15% | Valid Recall: 87.23% | Valid F1-score: 41.41% | Valid AUC-PR: 79.48%
# Time Elapsed: 1.75 minutes
# [Epoch 8, Batch 1] Loss: 0.0468
# [Epoch 8, Batch 369] Loss: 0.0655
# [Epoch 8, Batch 737] Loss: 0.0294
# [Epoch 8, Batch 1105] Loss: 0.1318
# [Epoch 8, Batch 1473] Loss: 0.0737
# [Epoch 8, Batch 1841] Loss: 0.0457
# [Epoch 8, Batch 2209] Loss: 0.0449
# [Epoch 8, Batch 2577] Loss: 0.0475
# [Epoch 8, Batch 2945] Loss: 0.0939
# [Epoch 8, Batch 3313] Loss: 0.0224
# [Epoch 8, Batch 3681] Loss: 0.0480
# Epoch 8/15: Train Loss: 0.0634 | Train Acc: 99.40% | Valid Loss: 0.0467 | Valid Acc: 99.63% | Valid Precision: 29.08% | Valid Recall: 87.23% | Valid F1-score: 43.62% | Valid AUC-PR: 78.79%
# Time Elapsed: 1.99 minutes
# [Epoch 9, Batch 1] Loss: 0.0567
# [Epoch 9, Batch 369] Loss: 0.2198
# [Epoch 9, Batch 737] Loss: 0.0721
# [Epoch 9, Batch 1105] Loss: 0.0251
# [Epoch 9, Batch 1473] Loss: 0.1489
# [Epoch 9, Batch 1841] Loss: 0.0775
# [Epoch 9, Batch 2209] Loss: 0.0387
# [Epoch 9, Batch 2577] Loss: 0.1197
# [Epoch 9, Batch 2945] Loss: 0.0271
# [Epoch 9, Batch 3313] Loss: 0.0262
# [Epoch 9, Batch 3681] Loss: 0.0729
# Epoch 9/15: Train Loss: 0.0623 | Train Acc: 99.47% | Valid Loss: 0.0451 | Valid Acc: 99.67% | Valid Precision: 31.66% | Valid Recall: 87.23% | Valid F1-score: 46.46% | Valid AUC-PR: 79.18%
# Time Elapsed: 2.22 minutes
# Epoch 00009: reducing learning rate of group 0 to 3.0000e-07.
# [Epoch 10, Batch 1] Loss: 0.0396
# [Epoch 10, Batch 369] Loss: 0.0584
# [Epoch 10, Batch 737] Loss: 0.0399
# [Epoch 10, Batch 1105] Loss: 0.0244
# [Epoch 10, Batch 1473] Loss: 0.0385
# [Epoch 10, Batch 1841] Loss: 0.2604
# [Epoch 10, Batch 2209] Loss: 0.0564
# [Epoch 10, Batch 2577] Loss: 0.0486
# [Epoch 10, Batch 2945] Loss: 0.0938
# [Epoch 10, Batch 3313] Loss: 0.1206
# [Epoch 10, Batch 3681] Loss: 0.0197
# Epoch 10/15: Train Loss: 0.0620 | Train Acc: 99.38% | Valid Loss: 0.0373 | Valid Acc: 99.77% | Valid Precision: 40.59% | Valid Recall: 87.23% | Valid F1-score: 55.41% | Valid AUC-PR: 79.34%
# Time Elapsed: 2.47 minutes
# [Epoch 11, Batch 1] Loss: 0.0378
# [Epoch 11, Batch 369] Loss: 0.0350
# [Epoch 11, Batch 737] Loss: 0.0379
# [Epoch 11, Batch 1105] Loss: 0.0525
# [Epoch 11, Batch 1473] Loss: 0.2050
# [Epoch 11, Batch 1841] Loss: 0.0363
# [Epoch 11, Batch 2209] Loss: 0.0560
# [Epoch 11, Batch 2577] Loss: 0.0551
# [Epoch 11, Batch 2945] Loss: 0.1084
# [Epoch 11, Batch 3313] Loss: 0.0323
# [Epoch 11, Batch 3681] Loss: 0.1481
# Epoch 11/15: Train Loss: 0.0632 | Train Acc: 99.35% | Valid Loss: 0.0327 | Valid Acc: 99.79% | Valid Precision: 43.39% | Valid Recall: 87.23% | Valid F1-score: 57.95% | Valid AUC-PR: 79.32%
# Time Elapsed: 2.72 minutes
# Early stopping triggered. Training stopped.
# Evaluating best saved model on test data.
# **Final Test Results:** Accuracy: 99.81%, Precision: 46.27%, Recall: 81.58%, F1-score: 59.05%, AUC-PR: 71.59%
# Metrics saved to metrics/FraudNet_64_15_3e-05_metrics.pickle
# Metrics visualization saved to plot_FraudNet_64_15_3e-05/train_metrics.png
# Metrics visualization saved to plot_FraudNet_64_15_3e-05/valid_metrics.png
# Confusion matrix visualization saved to plot_FraudNet_64_15_3e-05/confusion_matrix.png
# AUC-PR: 0.716, plot saved to plot_FraudNet_64_15_3e-05/auc_pr.png
# Loaded best model from training phase.
# Final best model saved explicitly at ./best_FraudNet_64_15_3e-05_model.pth
# Evaluating Model on Test Set...
# **Evaluation Results:**
# Accuracy   : 99.81%
# Precision  : 46.27%
# Recall     : 81.58%
# F1-score   : 59.05%
# AUC-ROC    : 98.47%
# AUC-PR    : 71.59%
# {'accuracy': 99.81055599612301,
#  'precision': 46.26865671641791,
#  'recall': 81.57894736842105,
#  'f1_score': 59.04761904761905,
#  'auc_roc': 98.47133831931993,
#  'auc_pr': 71.59385520862077}
